# %%
seq ="..."

reference = "ATGC"                                             #reference value
corrosponding = "TACG"                                         #corrosponding value
reversecompliment = seq.maketrans(reference,corrosponding)     #using  maketrans function  
print(seq.translate(reversecompliment)[::-1])
# Out:
# ...
